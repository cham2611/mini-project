# %%
import requests
from bs4 import BeautifulSoup

url = "https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
#Action "https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
#SinglePlayer https://store.steampowered.com/search/?filter=topsellers&tags=4182&supportedlang=english&ndl=1
#Adventure https://store.steampowered.com/search/?filter=topsellers&tags=21&supportedlang=english&ndl=1
#Indie https://store.steampowered.com/search/?filter=topsellers&tags=492&supportedlang=english&ndl=1
#Simulation https://store.steampowered.com/search/?filter=topsellers&tags=599&supportedlang=english&ndl=1
#Strategy https://store.steampowered.com/search/?filter=topsellers&tags=9&supportedlang=english&ndl=1
#Casual https://store.steampowered.com/search/?filter=topsellers&tags=597&supportedlang=english&ndl=1
#RPG https://store.steampowered.com/search/?filter=topsellers&tags=122&supportedlang=english&ndl=1
#Multiplayer https://store.steampowered.com/search/?filter=topsellers&tags=3859&supportedlang=english&ndl=1
#Atmospheric https://store.steampowered.com/search/?filter=topsellers&tags=4166&supportedlang=english&ndl=1
#2d https://store.steampowered.com/search/?filter=topsellers&tags=3871&supportedlang=english&ndl=1 
#story rich https://store.steampowered.com/search/?filter=topsellers&tags=1742&supportedlang=english&ndl=1
#co-op https://store.steampowered.com/search/?filter=topsellers&tags=1685&supportedlang=english&ndl=1
#first-person https://store.steampowered.com/search/?filter=topsellers&tags=3839&supportedlang=english&ndl=1
#3d https://store.steampowered.com/search/?filter=topsellers&tags=4191&supportedlang=english&ndl=1
#open world https://store.steampowered.com/search/?filter=topsellers&tags=1695&supportedlang=english&ndl=1

response = requests.get(url)
# , headers={
#     'cookie': 'steamCountry=KR!13817a80e36b14f1a94dd77fb2142a64; browserid=3999848730290483524; sessionid=2225f1149bbcf81b9631038f; timezoneOffset=32400,0; app_impressions=2344520@1_7_7_7000_150_1|2138330@1_7_7_7000_150_1|2358720@1_7_7_7000_150_1|2074920@1_7_7_7000_150_1|2183900@1_7_7_7000_150_1|1245620@1_7_7_7000_150_1|2139460@1_7_7_7000_150_1|1049590@1_7_7_7000_150_1|1091500@1_7_7_7000_150_1|578080@1_7_7_7000_150_1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
#     'accept-language':'ko-KR,ko;q=0.9',
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-encoding': 'gzip, deflate, br, zstd',
#     'cache-control':'no-cache'
# }

soup = BeautifulSoup(response.content, 'html.parser')

app_ids = []

container = soup.find('div', id='search_result_container')

if container:
    for item in container.find_all('a'):
        link =item['href']
        if 'app' in link:
            app_id = link.split('app')[1].split('/')[1]
            app_ids.append(app_id)

app_id=app_ids[:10]
app_id
# Out:
# ['578080',
#  '1049590',
#  '2139460',
#  '1091500',
#  '1245620',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2183900',
#  '2138330']

# %%
import requests
from bs4 import BeautifulSoup

urls = ["https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
,"https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
,"https://store.steampowered.com/search/?filter=topsellers&tags=4182&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=21&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=492&supportedlang=english&ndl=1"
," https://store.steampowered.com/search/?filter=topsellers&tags=599&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=9&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=597&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=122&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3859&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=4166&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3871&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1742&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1685&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3839&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=4191&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1695&supportedlang=english&ndl=1"]

app_id = []

for url in urls:
    response = requests.get(url)
# , headers={
#     'cookie': 'steamCountry=KR!13817a80e36b14f1a94dd77fb2142a64; browserid=3999848730290483524; sessionid=2225f1149bbcf81b9631038f; timezoneOffset=32400,0; app_impressions=2344520@1_7_7_7000_150_1|2138330@1_7_7_7000_150_1|2358720@1_7_7_7000_150_1|2074920@1_7_7_7000_150_1|2183900@1_7_7_7000_150_1|1245620@1_7_7_7000_150_1|2139460@1_7_7_7000_150_1|1049590@1_7_7_7000_150_1|1091500@1_7_7_7000_150_1|578080@1_7_7_7000_150_1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
#     'accept-language':'ko-KR,ko;q=0.9',
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-encoding': 'gzip, deflate, br, zstd',
#     'cache-control':'no-cache'
# }

    soup = BeautifulSoup(response.content, 'html.parser')

    app_ids = []

    container = soup.find('div', id='search_result_container')

    if container:
        for item in container.find_all('a'):
            link =item['href']
            if 'app' in link:
                ex = link.split('app')[1].split('/')[1]
                app_ids.append(ex)

    app_ids=app_ids[:10] # 상위 10개

    for i in range(len(app_ids)):
        app_id.append(app_ids[i])

app_id
# Out:
# ['578080',
#  '2139460',
#  '1049590',
#  '1091500',
#  '1245620',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2183900',
#  '2138330',
#  '578080',
#  '2139460',
#  '1049590',
#  '1091500',
#  '1245620',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2183900',
#  '2138330',
#  '2139460',
#  '1091500',
#  '1245620',
#  '2074920',
#  '2669320',
#  '1601580',
#  '2344520',
#  '2358720',
#  '2183900',
#  '2138330',
#  '2139460',
#  '1091500',
#  '2074920',
#  '2358720',
#  '2183900',
#  '2072450',
#  '1627720',
#  '2322010',
#  '1462040',
#  '108600',
#  '1049590',
#  '1260320',
#  '108600',
#  '2198150',
#  '227300',
#  '526870',
#  '1562700',
#  '1217060',
#  '1623730',
#  '2696050',
#  '578080',
#  '2139460',
#  '2669320',
#  '1601580',
#  '1665460',
#  '1158310',
#  '108600',
#  '1621690',
#  '2198150',
#  '1222670',
#  '578080',
#  '2139460',
#  '1049590',
#  '1601580',
#  '1158310',
#  '730',
#  '1142710',
#  '2161700',
#  '2021880',
#  '1973530',
#  '1260320',
#  '1621690',
#  '2198150',
#  '1222670',
#  '985810',
#  '227300',
#  '960170',
#  '2644470',
#  '413150',
#  '477160',
#  '2139460',
#  '1091500',
#  '1245620',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2138330',
#  '2072450',
#  '1627720',
#  '1158310',
#  '578080',
#  '2139460',
#  '1049590',
#  '1245620',
#  '2074920',
#  '2669320',
#  '2344520',
#  '2183900',
#  '1665460',
#  '1260320',
#  '1091500',
#  '1245620',
#  '1601580',
#  '2358720',
#  '2138330',
#  '1627720',
#  '2322010',
#  '1621690',
#  '1142710',
#  '2198150',
#  '108600',
#  '1621690',
#  '1973530',
#  '1449850',
#  '1562700',
#  '960170',
#  '413150',
#  '1147560',
#  '2401970',
#  '881100',
#  '1091500',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2138330',
#  '2072450',
#  '1627720',
#  '2322010',
#  '1462040',
#  '1142710',
#  '578080',
#  '2139460',
#  '1245620',
#  '2074920',
#  '2669320',
#  '2344520',
#  '2183900',
#  '1665460',
#  '1260320',
#  '108600',
#  '578080',
#  '1091500',
#  '2138330',
#  '730',
#  '1172470',
#  '2198150',
#  '271590',
#  '962130',
#  '526870',
#  '1966720',
#  '2139460',
#  '1049590',
#  '1245620',
#  '2358720',
#  '2183900',
#  '1627720',
#  '2322010',
#  '1462040',
#  '2021880',
#  '2515020',
#  '2139460',
#  '1091500',
#  '1245620',
#  '2138330',
#  '2322010',
#  '108600',
#  '227300',
#  '271590',
#  '1364780',
#  '962130']

# %%
import requests
import pandas as pd

# Steam Store API에서 특정 게임의 세부 정보를 가져오는 함수
def get_game_details(app_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={app_id}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data[str(app_id)]["success"]:
            game_data = data[str(app_id)]["data"]
            return {
                "app_id": app_id,
                "name": game_data.get("name"),
                "genres": ", ".join([genre['description'] for genre in game_data.get("genres", [])]),
                "header_image": game_data.get("header_image"),
                "release_date": game_data.get("release_date", {}).get("date"),  # 출시일 추가
                "price": game_data.get("price_overview", {}).get("final_formatted", "가격 정보 없음")  # 가격 추가
            }
    return {}

# Steam API를 통해 리뷰 데이터를 가져오는 함수
def get_reviews_for_game(app_id, num_reviews=100):
    url = f"https://store.steampowered.com/appreviews/{app_id}"
    params = {
        'json': 1,
        'num_per_page': num_reviews,  # 한 번에 가져올 리뷰 수
        'filter': 'recent',  # 최신 리뷰를 가져옴
        'language': 'english'  # 영어로 된 리뷰를 가져옴
    }
    response = requests.get(url, params=params)
    data = response.json()

    reviews = []

    if 'reviews' in data:
        for review in data['reviews']:
            reviews.append({
                'review_text': review.get('review'),
                'review_score': review.get('voted_up'),
                'language': review.get('language')
            })

    return reviews

# 게임 이름, 장르, 이미지, 사용자 평가 및 언어를 포함한 데이터를 DataFrame으로 정리하는 함수
def get_game_data_with_reviews(app_ids, num_reviews=100):
    all_data = []

    for app_id in app_ids:
        # 1. 게임 세부 정보 가져오기
        game_info = get_game_details(app_id)
        
        if game_info:
            # 2. 게임에 대한 리뷰 가져오기
            reviews = get_reviews_for_game(app_id, num_reviews)
            
            # 3. 각 리뷰에 게임 세부 정보 추가
            for review in reviews:
                all_data.append({
                    'app_id': game_info['app_id'],
                    'game_name': game_info['name'],
                    'game_genres': game_info['genres'],
                    'game_image': game_info['header_image'],
                    'game_release_date': game_info['release_date'],
                    'game_price': game_info['price'],
                    'review_text': review['review_text'],
                    'review_score': review['review_score'],
                    'language': review['language']
                })

    # 모든 데이터를 DataFrame으로 변환
    df = pd.DataFrame(all_data)
    return df

# 게임 데이터 및 리뷰 가져오기
df_game_data = get_game_data_with_reviews(app_id, num_reviews=50)  # 각 게임당 50개의 리뷰 가져오기

# CSV 파일로 저장
df_game_data.to_csv('ex.csv', index=False)

# %%
ex=pd.read_csv('ex.csv')
ex['app_id'].value_counts()
# Out:
# app_id
# 1091500    450
# 1245620    450
# 2358720    400
# 2138330    400
# 578080     350
# 2344520    350
# 2183900    350
# 108600     300
# 2322010    250
# 1627720    250
# 1260320    200
# 1621690    200
# 2669320    200
# 2198150    200
# 1601580    200
# 1665460    150
# 1158310    150
# 1462040    150
# 227300     150
# 2072450    150
# 1142710    150
# 1049590    114
# 271590     100
# 960170     100
# 962130     100
# 413150     100
# 730        100
# 526870     100
# 1222670    100
# 1562700    100
# 1966720     50
# 2515020     50
# 2401970     50
# 1172470     50
# 881100      50
# 2696050     50
# 1147560     50
# 477160      50
# 2644470     50
# 2161700     50
# 1623730     50
# 1217060     50
# 1364780     50
# Name: count, dtype: int64

# %%
['578080', # 1
 '1049590', # 2
 '1091500', # 3
 '2139460', # 4 X
 '1245620', # 5
 '2074920', # 6 X 
 '2183900', # 7
 '2358720', # 8
 '2344520', # 9
 '2138330'] # 10
# Out:
# ['578080',
#  '1049590',
#  '1091500',
#  '2139460',
#  '1245620',
#  '2074920',
#  '2183900',
#  '2358720',
#  '2344520',
#  '2138330']

# %%
def get_game_data(app_id): # 이미지, id , 이름, 장르 정상적으로 작동 
    url = f"https://store.steampowered.com/api/appdetails?appids={app_id}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data[str(app_id)]["success"]:
            game_data = data[str(app_id)]["data"]
            return {
                "app_id": app_id,
                "name": game_data.get("name"),
                "genres": ", ".join([genre['description'] for genre in game_data.get("genres", [])]),
                "header_image": game_data.get("header_image"),
            }
    return None  # 응답이 성공적이지 않은 경우 None 반환

# 사용 예시
game_info = get_game_data(2074920)
print(game_info)
# Out:
# {'app_id': 2074920, 'name': 'The First Descendant', 'genres': 'Action, Adventure, RPG, Free To Play', 'header_image': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2074920/header.jpg?t=1725356337'}

# %%
# Steam API를 통해 리뷰 데이터를 가져오는 함수 # 2139460, 2074920 정상적으로 작동 x 

url = f"https://store.steampowered.com/appreviews/{1049590}"
params = {
        'json': 1,
        'num_per_page': 50,  # 한 번에 가져올 리뷰 수
        'filter': 'recent',  # 최신 리뷰를 가져옴
        'language': 'english'  # 모든 언어로 된 리뷰를 가져옴
}
response = requests.get(url, params=params)
data = response.json()
data
# Out:
# {'success': 1,
#  'query_summary': {'num_reviews': 19,
#   'review_score': 7,
#   'review_score_desc': 'Positive',
#   'total_positive': 17,
#   'total_negative': 2,
#   'total_reviews': 19},
#  'reviews': [{'recommendationid': '158772871',
#    'author': {'steamid': '76561198110879950',
#     'num_games_owned': 310,
#     'num_reviews': 29,
#     'playtime_forever': 2554,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 2554,
#     'last_played': 1713109849},
#    'language': 'english',
#    'review': "The game is a commercial failure. Wouldn't surprise me if it EOS'd soon.",
#    'timestamp_created': 1708398574,
#    'timestamp_updated': 1723997501,
#    'voted_up': False,
#    'votes_up': 3,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.484944522380828857',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'hidden_in_steam_china': True,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '105095478',
#    'author': {'steamid': '76561198208821009',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 438,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 279,
#     'last_played': 1662541937},
#    'language': 'english',
#    'review': 'one thing give a slight nerf on op bianca?\n',
#    'timestamp_created': 1638476898,
#    'timestamp_updated': 1638476898,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '101996577',
#    'author': {'steamid': '76561198200647247',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 145996,
#     'playtime_last_two_weeks': 3020,
#     'playtime_at_review': 3700,
#     'last_played': 1727139326},
#    'language': 'english',
#    'review': 'Fun af.\nEdit: About 1500 hours later game is currently in the best state its ever been in for new players and I highly recommend trying it out if you are interested.',
#    'timestamp_created': 1635721171,
#    'timestamp_updated': 1690362813,
#    'voted_up': True,
#    'votes_up': 1,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '95153607',
#    'author': {'steamid': '76561198276917081',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 3100,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 417,
#     'last_played': 1690409855},
#    'language': 'english',
#    'review': 'actually addicting',
#    'timestamp_created': 1625543925,
#    'timestamp_updated': 1625543925,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '91362651',
#    'author': {'steamid': '76561198182529301',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 28711,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 24060,
#     'last_played': 1715074095},
#    'language': 'english',
#    'review': 'fun game challenging and overall good community so far.',
#    'timestamp_created': 1620058458,
#    'timestamp_updated': 1620058458,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '90984821',
#    'author': {'steamid': '76561198143137077',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 1516,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 1371,
#     'last_played': 1708325189},
#    'language': 'english',
#    'review': 'game is actually good just needs more publicity',
#    'timestamp_created': 1619494311,
#    'timestamp_updated': 1619494311,
#    'voted_up': True,
#    'votes_up': 3,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.549114346504211426',
#    'comment_count': 1,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '89441763',
#    'author': {'steamid': '76561198083275192',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 1795,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 1771,
#     'last_played': 1619291666},
#    'language': 'english',
#    'review': "Awesome game so far. I'd reccomend to anyone who's into moba/survival games.",
#    'timestamp_created': 1617207822,
#    'timestamp_updated': 1617207822,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.476190477609634399',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '89391163',
#    'author': {'steamid': '76561198158970302',
#     'num_games_owned': 0,
#     'num_reviews': 5,
#     'playtime_forever': 10098,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 4051,
#     'last_played': 1703731182},
#    'language': 'english',
#    'review': 'good shit',
#    'timestamp_created': 1617134535,
#    'timestamp_updated': 1617134535,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.476190477609634399',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '88974110',
#    'author': {'steamid': '76561197985020355',
#     'num_games_owned': 79,
#     'num_reviews': 10,
#     'playtime_forever': 6192,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 1266,
#     'last_played': 1618521309},
#    'language': 'english',
#    'review': 'Just fun',
#    'timestamp_created': 1616544996,
#    'timestamp_updated': 1616544996,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '88261746',
#    'author': {'steamid': '76561198134425022',
#     'num_games_owned': 0,
#     'num_reviews': 11,
#     'playtime_forever': 29105,
#     'playtime_last_two_weeks': 825,
#     'playtime_at_review': 2612,
#     'last_played': 1727045278},
#    'language': 'english',
#    'review': 'A true gem of a game.',
#    'timestamp_created': 1615492526,
#    'timestamp_updated': 1615492526,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.516707241535186768',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '88024166',
#    'author': {'steamid': '76561198417546559',
#     'num_games_owned': 0,
#     'num_reviews': 11,
#     'playtime_forever': 16633,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 1756,
#     'last_played': 1692979402},
#    'language': 'english',
#    'review': 'Good game',
#    'timestamp_created': 1615128701,
#    'timestamp_updated': 1615128701,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '87585907',
#    'author': {'steamid': '76561198801322441',
#     'num_games_owned': 0,
#     'num_reviews': 1,
#     'playtime_forever': 1167,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 195,
#     'last_played': 1693506907},
#    'language': 'english',
#    'review': 'this game awesome\n',
#    'timestamp_created': 1614488311,
#    'timestamp_updated': 1614488311,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '85893341',
#    'author': {'steamid': '76561198035516617',
#     'num_games_owned': 75,
#     'num_reviews': 2,
#     'playtime_forever': 7495,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 750,
#     'last_played': 1699910915},
#    'language': 'english',
#    'review': 'This game give a lot of have ;D',
#    'timestamp_created': 1612370841,
#    'timestamp_updated': 1612370841,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '84289734',
#    'author': {'steamid': '76561198138655777',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 31154,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 5263,
#     'last_played': 1693997841},
#    'language': 'english',
#    'review': 'If LOL is wine, Eternal Return is coffee. \nEven if you swear and press "Not recommended," you will eventually play the game again.',
#    'timestamp_created': 1610112900,
#    'timestamp_updated': 1631276659,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': True,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '78340695',
#    'author': {'steamid': '76561198084922456',
#     'num_games_owned': 0,
#     'num_reviews': 14,
#     'playtime_forever': 9316,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 2137,
#     'last_played': 1667839817},
#    'language': 'english',
#    'review': 'addictive yet sht game lul',
#    'timestamp_created': 1603981535,
#    'timestamp_updated': 1603981640,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.490070044994354248',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '78167636',
#    'author': {'steamid': '76561198107322630',
#     'num_games_owned': 0,
#     'num_reviews': 93,
#     'playtime_forever': 3225,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 218,
#     'last_played': 1654336145},
#    'language': 'english',
#    'review': "Really nice game got some sick fresh elements integrated. HOWEVER, the biggest concern is the servers they have. Right now there's only realistically 4-5 servers running and I hear EU servers arent always up and if you're like me who lives in Australia which needs a Oceania server which doesnt exist then you're looking about 250 ping to play which lags liike crazy on Asia & US server.\nWill change to a thumbs up once they've added new servers in hopefully this game continues to grow as I have high hopes for it!\n\nUPDATE: Pretty disappointed at how the management is with this game as they try to do a lot of banning and not to mention banning stream snipers instead of focusing more time on actually trying to open new servers up so to get more exposure for the game.....Right now it's kind of a turn off so decided to uninstall it.\n\nUPDATE 2: The good news is that other servers are up but unfortunately it's leaving players wants to support that are in the Oceania region super dead clearly the devs should be more transparent about this so now they just seem to avoid the question all together........",
#    'timestamp_created': 1603686610,
#    'timestamp_updated': 1618571165,
#    'voted_up': False,
#    'votes_up': 52,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.669424712657928467',
#    'comment_count': 6,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False,
#    'timestamp_dev_responded': 1616493568,
#    'developer_response': "Hey friend! Sorry to hear you're upset with the servers.\n\nAs the game has just launched, we're opening new servres slowly. We want to gather initial data on where prime server locations would be inside regions and we also want to try to avoid long queues on lesser populated servers. Queue times even on the NA server can get long during off-peak hours, resulting in frustration for players, and we'd like to avoid that. Opening some servers for just a few hours allows us to congregate players and have them get more games in and have more fun. \n\nMore servers and 24/7 up time is the goal, so we'll keep working towards it.\n\n(Edit: In case someone stumbles upon this review in the future, NA, SA, EU, HK, KR servers are up 24/7)"},
#   {'recommendationid': '77925748',
#    'author': {'steamid': '76561198103496485',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 304,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 36,
#     'last_played': 1603654780},
#    'language': 'english',
#    'review': 'I played the game on mobile and enjoyed it very much\nHowever unlike the mobile game it is more like league of legends than a VN. imagine a mix of League of Legends Pubg and The long Dark. The game is still new and i am very excited to see where it goes',
#    'timestamp_created': 1603296101,
#    'timestamp_updated': 1603296101,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '77677009',
#    'author': {'steamid': '76561198079765162',
#     'num_games_owned': 0,
#     'num_reviews': 11,
#     'playtime_forever': 914,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 816,
#     'last_played': 1603760384},
#    'language': 'english',
#    'review': "Great game with standard beta issues, hoping for more balance options, new modes, and characters with time. \nI'd also like more control input options, like keyboard accessibility, instead of only mouse (WASD).",
#    'timestamp_created': 1602896103,
#    'timestamp_updated': 1602896103,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False},
#   {'recommendationid': '77571292',
#    'author': {'steamid': '76561198072951350',
#     'num_games_owned': 0,
#     'num_reviews': 3,
#     'playtime_forever': 2420,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 226,
#     'last_played': 1605635736},
#    'language': 'english',
#    'review': 'fun game',
#    'timestamp_created': 1602716550,
#    'timestamp_updated': 1602716550,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': 0,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': True,
#    'written_during_early_access': True,
#    'hidden_in_steam_china': False,
#    'steam_china_location': '',
#    'primarily_steam_deck': False}],
#  'cursor': 'AoJwt7jWlPUCfM30pwI='}

# %%
ex
# Out:
#       app_id            game_name  \
# 0     578080  PUBG: BATTLEGROUNDS
# 1     578080  PUBG: BATTLEGROUNDS
# 2     578080  PUBG: BATTLEGROUNDS
# 3     578080  PUBG: BATTLEGROUNDS
# 4     578080  PUBG: BATTLEGROUNDS
# ...      ...                  ...
# 7009  962130             Grounded
# 7010  962130             Grounded
# 7011  962130             Grounded
# 7012  962130             Grounded
# 7013  962130             Grounded
#
#                                             game_genres  \
# 0     Action, Adventure, Massively Multiplayer, Free...
# 1     Action, Adventure, Massively Multiplayer, Free...
# 2     Action, Adventure, Massively Multiplayer, Free...
# 3     Action, Adventure, Massively Multiplayer, Free...
# 4     Action, Adventure, Massively Multiplayer, Free...
# ...                                                 ...
# 7009                                  Action, Adventure
# 7010                                  Action, Adventure
# 7011                                  Action, Adventure
# 7012                                  Action, Adventure
# 7013                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7009  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7010  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7011  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7012  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7013  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음                         Cancer bad disgusting game
# 1      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 2      가격 정보 없음  The game is good overall fun to play but Full ...
# 3      가격 정보 없음  best game except hackers but lately its not as...
# 4      가격 정보 없음                                           its okey
# ...         ...                                                ...
# 7009   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7010   ₩ 19,950  This is an all around great game . Fun to play...
# 7011   ₩ 19,950  Really fun. I hate the lag but that's just my ...
# 7012   ₩ 19,950  [h1] I didn't expect how much I would like thi...
# 7013   ₩ 19,950  I love this game. No other crafting survival g...
#
#       review_score language
# 0            False  english
# 1             True  english
# 2             True  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7009          True  english
# 7010          True  english
# 7011          True  english
# 7012          True  english
# 7013          True  english
#
# [7014 rows x 9 columns]

# %%
ex1= ex.copy()
ex1
# Out:
#       app_id            game_name  \
# 0     578080  PUBG: BATTLEGROUNDS
# 1     578080  PUBG: BATTLEGROUNDS
# 2     578080  PUBG: BATTLEGROUNDS
# 3     578080  PUBG: BATTLEGROUNDS
# 4     578080  PUBG: BATTLEGROUNDS
# ...      ...                  ...
# 7009  962130             Grounded
# 7010  962130             Grounded
# 7011  962130             Grounded
# 7012  962130             Grounded
# 7013  962130             Grounded
#
#                                             game_genres  \
# 0     Action, Adventure, Massively Multiplayer, Free...
# 1     Action, Adventure, Massively Multiplayer, Free...
# 2     Action, Adventure, Massively Multiplayer, Free...
# 3     Action, Adventure, Massively Multiplayer, Free...
# 4     Action, Adventure, Massively Multiplayer, Free...
# ...                                                 ...
# 7009                                  Action, Adventure
# 7010                                  Action, Adventure
# 7011                                  Action, Adventure
# 7012                                  Action, Adventure
# 7013                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7009  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7010  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7011  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7012  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7013  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음                         Cancer bad disgusting game
# 1      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 2      가격 정보 없음  The game is good overall fun to play but Full ...
# 3      가격 정보 없음  best game except hackers but lately its not as...
# 4      가격 정보 없음                                           its okey
# ...         ...                                                ...
# 7009   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7010   ₩ 19,950  This is an all around great game . Fun to play...
# 7011   ₩ 19,950  Really fun. I hate the lag but that's just my ...
# 7012   ₩ 19,950  [h1] I didn't expect how much I would like thi...
# 7013   ₩ 19,950  I love this game. No other crafting survival g...
#
#       review_score language
# 0            False  english
# 1             True  english
# 2             True  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7009          True  english
# 7010          True  english
# 7011          True  english
# 7012          True  english
# 7013          True  english
#
# [7014 rows x 9 columns]

# %%
ex1=ex1.drop(['app_id', ], axis=1) # app_id 삭제

# %%
ex1 = ex1[ex1['language'] == 'english'] # english 
ex1 = ex1.reset_index(drop=True) # 재정렬
ex1
# Out:
#                 game_name                                        game_genres  \
# 0     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 1     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 2     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 3     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 4     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# ...                   ...                                                ...
# 7009             Grounded                                  Action, Adventure
# 7010             Grounded                                  Action, Adventure
# 7011             Grounded                                  Action, Adventure
# 7012             Grounded                                  Action, Adventure
# 7013             Grounded                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7009  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7010  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7011  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7012  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7013  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음                         Cancer bad disgusting game
# 1      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 2      가격 정보 없음  The game is good overall fun to play but Full ...
# 3      가격 정보 없음  best game except hackers but lately its not as...
# 4      가격 정보 없음                                           its okey
# ...         ...                                                ...
# 7009   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7010   ₩ 19,950  This is an all around great game . Fun to play...
# 7011   ₩ 19,950  Really fun. I hate the lag but that's just my ...
# 7012   ₩ 19,950  [h1] I didn't expect how much I would like thi...
# 7013   ₩ 19,950  I love this game. No other crafting survival g...
#
#       review_score language
# 0            False  english
# 1             True  english
# 2             True  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7009          True  english
# 7010          True  english
# 7011          True  english
# 7012          True  english
# 7013          True  english
#
# [7014 rows x 8 columns]

# %%
# CSV 파일로 저장
ex1.to_csv('ex1.csv', index=False)

# %%
Example=pd.read_csv('ex1.csv')
Example
# Out:
#                 game_name                                        game_genres  \
# 0     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 1     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 2     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 3     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 4     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# ...                   ...                                                ...
# 7009             Grounded                                  Action, Adventure
# 7010             Grounded                                  Action, Adventure
# 7011             Grounded                                  Action, Adventure
# 7012             Grounded                                  Action, Adventure
# 7013             Grounded                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7009  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7010  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7011  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7012  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7013  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음                         Cancer bad disgusting game
# 1      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 2      가격 정보 없음  The game is good overall fun to play but Full ...
# 3      가격 정보 없음  best game except hackers but lately its not as...
# 4      가격 정보 없음                                           its okey
# ...         ...                                                ...
# 7009   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7010   ₩ 19,950  This is an all around great game . Fun to play...
# 7011   ₩ 19,950  Really fun. I hate the lag but that's just my ...
# 7012   ₩ 19,950  [h1] I didn't expect how much I would like thi...
# 7013   ₩ 19,950  I love this game. No other crafting survival g...
#
#       review_score language
# 0            False  english
# 1             True  english
# 2             True  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7009          True  english
# 7010          True  english
# 7011          True  english
# 7012          True  english
# 7013          True  english
#
# [7014 rows x 8 columns]

# %%
# Example['game_name'] 7014
# Example['game_genres'] 7014
# Example['game_image'] 7014
# Example['game_release_date'] 7014
# Example['game_price'] 7014
# Example['review_text'] 7014
# Example['review_score'] 7014
# Example['language'] 7014
# Out:
# 0       english
# 1       english
# 2       english
# 3       english
# 4       english
#          ...
# 7009    english
# 7010    english
# 7011    english
# 7012    english
# 7013    english
# Name: language, Length: 7014, dtype: object

# %%
for  index, row in Example.iterrows():
    data_tuple = (
        row['game_name'],
        row['game_genres'],
        row['game_image'],
        row['game_release_date'],
        row['game_price'],
        row['review_text'],
        row['review_score'],
        row['language']
    )
data_tuple
# Out:
# ('Grounded',
#  'Action, Adventure',
#  'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/962130/header.jpg?t=1715361019',
#  '27 Sep, 2022',
#  '₩ 19,950',
#  'I love this game. No other crafting survival games can compare after playing Grounded. I compare everything to it. Thank goodness for new game plus! Such a good game',
#  True,
#  'english')

# %%
# 날짜 형식 변환
Example['game_release_date'] = pd.to_datetime(Example['game_release_date'], format='%b %d, %Y')

# %%
# 날짜 형식 변환 함수 정의
def parse_date(date_str):
    try:
        # 'Sep 19, 2024' 형식
        return pd.to_datetime(date_str, format='%b %d, %Y')
    except ValueError:
        pass
    try:
        # '19 Sep, 2024' 형식
        return pd.to_datetime(date_str, format='%d %b, %Y')
    except ValueError:
        pass
    return pd.NaT  # 변환할 수 없는 경우 NaT 반환

# 데이터프레임의 날짜 열 변환
Example['game_release_date'] = Example['game_release_date'].apply(parse_date)

Example['game_release_date']
# Out:
# 0      2017-12-21
# 1      2017-12-21
# 2      2017-12-21
# 3      2017-12-21
# 4      2017-12-21
#           ...
# 7009   2022-09-27
# 7010   2022-09-27
# 7011   2022-09-27
# 7012   2022-09-27
# 7013   2022-09-27
# Name: game_release_date, Length: 7014, dtype: datetime64[ns]

# %%
Example
# Out:
#                 game_name                                        game_genres  \
# 0     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 1     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 2     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 3     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 4     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# ...                   ...                                                ...
# 7009             Grounded                                  Action, Adventure
# 7010             Grounded                                  Action, Adventure
# 7011             Grounded                                  Action, Adventure
# 7012             Grounded                                  Action, Adventure
# 7013             Grounded                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 1     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 2     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 3     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 4     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# ...                                                 ...               ...
# 7009  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7010  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7011  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7012  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7013  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
#
#      game_price                                        review_text  \
# 0      가격 정보 없음                         Cancer bad disgusting game
# 1      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 2      가격 정보 없음  The game is good overall fun to play but Full ...
# 3      가격 정보 없음  best game except hackers but lately its not as...
# 4      가격 정보 없음                                           its okey
# ...         ...                                                ...
# 7009   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7010   ₩ 19,950  This is an all around great game . Fun to play...
# 7011   ₩ 19,950  Really fun. I hate the lag but that's just my ...
# 7012   ₩ 19,950  [h1] I didn't expect how much I would like thi...
# 7013   ₩ 19,950  I love this game. No other crafting survival g...
#
#       review_score language
# 0            False  english
# 1             True  english
# 2             True  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7009          True  english
# 7010          True  english
# 7011          True  english
# 7012          True  english
# 7013          True  english
#
# [7014 rows x 8 columns]

# %%
Example['game_price'] 


# 숫자만 추출하는 함수
def extract_numbers(price_str):
    # 숫자를 저장할 빈 문자열
    numbers = ''
    
    # 문자열을 하나씩 검사
    for char in price_str:
        # 각 문자가 숫자이거나 쉼표일 경우
        if char.isdigit() or char == ',':
            # numbers 문자열에 추가
            numbers += char
    
    # 쉼표를 제거하고 숫자 문자열을 정수로 변환
    return int(numbers.replace(',', ''))

# 함수 사용 예
Example['game_price']  = extract_numbers(Example['game_price'] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 20
#      17     return int(numbers.replace(',', ''))
#      19 # 함수 사용 예
# ---> 20 Example['game_price']  = extract_numbers(Example['game_price'] )
#
# Cell In[157], line 17, in extract_numbers(price_str)
#      14         numbers += char
#      16 # 쉼표를 제거하고 숫자 문자열을 정수로 변환
# ---> 17 return int(numbers.replace(',', ''))
#
# ValueError: invalid literal for int() with base 10: ''
