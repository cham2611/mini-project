# %%
import requests
from bs4 import BeautifulSoup

urls = ["https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
,"https://store.steampowered.com/search/?tags=19&supportedlang=english&filter=topsellers&ndl=1" 
,"https://store.steampowered.com/search/?filter=topsellers&tags=4182&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=21&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=492&supportedlang=english&ndl=1"
," https://store.steampowered.com/search/?filter=topsellers&tags=599&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=9&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=597&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=122&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3859&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=4166&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3871&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1742&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1685&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=3839&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=4191&supportedlang=english&ndl=1"
,"https://store.steampowered.com/search/?filter=topsellers&tags=1695&supportedlang=english&ndl=1"]

app_id = []

for url in urls:
    response = requests.get(url)
# , headers={
#     'cookie': 'steamCountry=KR!13817a80e36b14f1a94dd77fb2142a64; browserid=3999848730290483524; sessionid=2225f1149bbcf81b9631038f; timezoneOffset=32400,0; app_impressions=2344520@1_7_7_7000_150_1|2138330@1_7_7_7000_150_1|2358720@1_7_7_7000_150_1|2074920@1_7_7_7000_150_1|2183900@1_7_7_7000_150_1|1245620@1_7_7_7000_150_1|2139460@1_7_7_7000_150_1|1049590@1_7_7_7000_150_1|1091500@1_7_7_7000_150_1|578080@1_7_7_7000_150_1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
#     'accept-language':'ko-KR,ko;q=0.9',
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-encoding': 'gzip, deflate, br, zstd',
#     'cache-control':'no-cache'
# }

    soup = BeautifulSoup(response.content, 'html.parser')

    app_ids = []

    container = soup.find('div', id='search_result_container')

    if container:
        for item in container.find_all('a'):
            link =item['href']
            if 'app' in link:
                ex = link.split('app')[1].split('/')[1]
                app_ids.append(ex)

    app_ids=app_ids[:10] # 상위 10개

    for i in range(len(app_ids)):
        app_id.append(app_ids[i])

app_id
# Out:
# ['578080',
#  '1049590',
#  '2139460',
#  '1091500',
#  '2074920',
#  '1245620',
#  '2344520',
#  '2358720',
#  '2322010',
#  '2138330',
#  '578080',
#  '1049590',
#  '2139460',
#  '1091500',
#  '2074920',
#  '1245620',
#  '2344520',
#  '2358720',
#  '2322010',
#  '2138330',
#  '2139460',
#  '1091500',
#  '2074920',
#  '1245620',
#  '1601580',
#  '2344520',
#  '2358720',
#  '2322010',
#  '2138330',
#  '2183900',
#  '2139460',
#  '1091500',
#  '2074920',
#  '2358720',
#  '2322010',
#  '2183900',
#  '1462040',
#  '108600',
#  '2072450',
#  '1364780',
#  '1049590',
#  '1260320',
#  '2198150',
#  '108600',
#  '227300',
#  '526870',
#  '1562700',
#  '1623730',
#  '1217060',
#  '477160',
#  '578080',
#  '2139460',
#  '1601580',
#  '1158310',
#  '2198150',
#  '108600',
#  '1665460',
#  '1621690',
#  '1222670',
#  '502500',
#  '578080',
#  '1049590',
#  '2139460',
#  '1601580',
#  '1158310',
#  '2021880',
#  '2161700',
#  '1142710',
#  '1973530',
#  '730',
#  '1260320',
#  '2198150',
#  '985810',
#  '1621690',
#  '1222670',
#  '227300',
#  '960170',
#  '2644470',
#  '477160',
#  '413150',
#  '2139460',
#  '1091500',
#  '2074920',
#  '1245620',
#  '2344520',
#  '2358720',
#  '2322010',
#  '2138330',
#  '1158310',
#  '1462040',
#  '578080',
#  '1049590',
#  '2139460',
#  '2074920',
#  '1245620',
#  '2344520',
#  '2183900',
#  '1158310',
#  '1260320',
#  '108600',
#  '1091500',
#  '1245620',
#  '1601580',
#  '2358720',
#  '2322010',
#  '2138330',
#  '2198150',
#  '1627720',
#  '2515020',
#  '1621690',
#  '108600',
#  '1621690',
#  '1973530',
#  '1449850',
#  '1562700',
#  '960170',
#  '413150',
#  '1147560',
#  '322330',
#  '2401970',
#  '1091500',
#  '2074920',
#  '2344520',
#  '2358720',
#  '2322010',
#  '2138330',
#  '1462040',
#  '2072450',
#  '1627720',
#  '2161700',
#  '578080',
#  '2139460',
#  '2074920',
#  '1245620',
#  '2344520',
#  '2183900',
#  '1260320',
#  '108600',
#  '1665460',
#  '1172470',
#  '578080',
#  '1091500',
#  '2138330',
#  '2198150',
#  '1172470',
#  '730',
#  '502500',
#  '271590',
#  '962130',
#  '526870',
#  '1049590',
#  '2139460',
#  '1245620',
#  '2358720',
#  '2322010',
#  '2183900',
#  '1462040',
#  '1364780',
#  '2021880',
#  '1627720',
#  '2139460',
#  '1091500',
#  '1245620',
#  '2322010',
#  '2138330',
#  '108600',
#  '1364780',
#  '271590',
#  '2054970',
#  '962130']

# %%
import requests
import pandas as pd

# Steam Store API에서 특정 게임의 세부 정보를 가져오는 함수
def get_game_details(app_id):
    url = f"https://store.steampowered.com/api/appdetails?appids={app_id}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data[str(app_id)]["success"]:
            game_data = data[str(app_id)]["data"]
            return {
                "app_id": app_id,
                "name": game_data.get("name"),
                "genres": ", ".join([genre['description'] for genre in game_data.get("genres", [])]),
                "header_image": game_data.get("header_image"),
                "release_date": game_data.get("release_date", {}).get("date"),  # 출시일 추가
                "price": game_data.get("price_overview", {}).get("final_formatted", "가격 정보 없음")  # 가격 추가
            }
    return {}

# Steam API를 통해 리뷰 데이터를 가져오는 함수
def get_reviews_for_game(app_id, num_reviews=100):
    url = f"https://store.steampowered.com/appreviews/{app_id}"
    params = {
        'json': 1,
        'num_per_page': num_reviews,  # 한 번에 가져올 리뷰 수
        'filter': 'recent',  # 최신 리뷰를 가져옴
        'language': 'english'  # 영어로 된 리뷰를 가져옴
    }
    response = requests.get(url, params=params)
    data = response.json()

    reviews = []

    if 'reviews' in data:
        for review in data['reviews']:
            reviews.append({
                'review_text': review.get('review'),
                'review_score': review.get('voted_up'),
                'language': review.get('language')
            })

    return reviews

# 게임 이름, 장르, 이미지, 사용자 평가 및 언어를 포함한 데이터를 DataFrame으로 정리하는 함수
def get_game_data_with_reviews(app_ids, num_reviews=100):
    all_data = []

    for app_id in app_ids:
        # 1. 게임 세부 정보 가져오기
        game_info = get_game_details(app_id)
        
        if game_info:
            # 2. 게임에 대한 리뷰 가져오기
            reviews = get_reviews_for_game(app_id, num_reviews)
            
            # 3. 각 리뷰에 게임 세부 정보 추가
            for review in reviews:
                all_data.append({
                    'app_id': game_info['app_id'],
                    'game_name': game_info['name'],
                    'game_genres': game_info['genres'],
                    'game_image': game_info['header_image'],
                    'game_release_date': game_info['release_date'],
                    'game_price': game_info['price'],
                    'review_text': review['review_text'],
                    'review_score': review['review_score'],
                    'language': review['language']
                })

    # 모든 데이터를 DataFrame으로 변환
    df = pd.DataFrame(all_data)
    return df

# 게임 데이터 및 리뷰 가져오기
df_game_data = get_game_data_with_reviews(app_id, num_reviews=50)  # 각 게임당 50개의 리뷰 가져오기

# CSV 파일로 저장
df_game_data.to_csv('finally.csv', index=False)

# %%
Example=pd.read_csv('finally.csv')
Example
# Out:
#       app_id            game_name  \
# 0     578080  PUBG: BATTLEGROUNDS
# 1     578080  PUBG: BATTLEGROUNDS
# 2     578080  PUBG: BATTLEGROUNDS
# 3     578080  PUBG: BATTLEGROUNDS
# 4     578080  PUBG: BATTLEGROUNDS
# ...      ...                  ...
# 7059  962130             Grounded
# 7060  962130             Grounded
# 7061  962130             Grounded
# 7062  962130             Grounded
# 7063  962130             Grounded
#
#                                             game_genres  \
# 0     Action, Adventure, Massively Multiplayer, Free...
# 1     Action, Adventure, Massively Multiplayer, Free...
# 2     Action, Adventure, Massively Multiplayer, Free...
# 3     Action, Adventure, Massively Multiplayer, Free...
# 4     Action, Adventure, Massively Multiplayer, Free...
# ...                                                 ...
# 7059                                  Action, Adventure
# 7060                                  Action, Adventure
# 7061                                  Action, Adventure
# 7062                                  Action, Adventure
# 7063                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7059  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7060  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7061  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7062  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7063  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음  the game is generally good, it is even interes...
# 1      가격 정보 없음  I liked it better when it wasnt a free game, b...
# 2      가격 정보 없음                         Cancer bad disgusting game
# 3      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 4      가격 정보 없음  The game is good overall fun to play but Full ...
# ...         ...                                                ...
# 7059   ₩ 19,950                                            perfect
# 7060   ₩ 19,950                                     I hate bugs...
# 7061   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7062   ₩ 19,950  This is an all around great game . Fun to play...
# 7063   ₩ 19,950  Really fun. I hate the lag but that's just my ...
#
#       review_score language
# 0             True  english
# 1             True  english
# 2            False  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7059          True  english
# 7060          True  english
# 7061          True  english
# 7062          True  english
# 7063          True  english
#
# [7064 rows x 9 columns]

# %%
Example['app_id'].value_counts()
# Out:
# app_id
# 1091500    450
# 1245620    450
# 2322010    450
# 2358720    400
# 2138330    400
# 578080     350
# 2344520    350
# 108600     350
# 2183900    250
# 2198150    250
# 1601580    200
# 1462040    200
# 1621690    200
# 1158310    200
# 1260320    200
# 1627720    150
# 1364780    150
# 1049590    114
# 1172470    100
# 271590     100
# 413150     100
# 960170     100
# 502500     100
# 730        100
# 962130     100
# 2161700    100
# 477160     100
# 1222670    100
# 1665460    100
# 1562700    100
# 526870     100
# 227300     100
# 2072450    100
# 1142710     50
# 1217060     50
# 2644470     50
# 1623730     50
# 2515020     50
# 1147560     50
# 322330      50
# 2401970     50
# 2054970     50
# Name: count, dtype: int64

# %%
Example1= Example.copy()
Example1
# Out:
#       app_id            game_name  \
# 0     578080  PUBG: BATTLEGROUNDS
# 1     578080  PUBG: BATTLEGROUNDS
# 2     578080  PUBG: BATTLEGROUNDS
# 3     578080  PUBG: BATTLEGROUNDS
# 4     578080  PUBG: BATTLEGROUNDS
# ...      ...                  ...
# 7059  962130             Grounded
# 7060  962130             Grounded
# 7061  962130             Grounded
# 7062  962130             Grounded
# 7063  962130             Grounded
#
#                                             game_genres  \
# 0     Action, Adventure, Massively Multiplayer, Free...
# 1     Action, Adventure, Massively Multiplayer, Free...
# 2     Action, Adventure, Massively Multiplayer, Free...
# 3     Action, Adventure, Massively Multiplayer, Free...
# 4     Action, Adventure, Massively Multiplayer, Free...
# ...                                                 ...
# 7059                                  Action, Adventure
# 7060                                  Action, Adventure
# 7061                                  Action, Adventure
# 7062                                  Action, Adventure
# 7063                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7059  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7060  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7061  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7062  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7063  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음  the game is generally good, it is even interes...
# 1      가격 정보 없음  I liked it better when it wasnt a free game, b...
# 2      가격 정보 없음                         Cancer bad disgusting game
# 3      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 4      가격 정보 없음  The game is good overall fun to play but Full ...
# ...         ...                                                ...
# 7059   ₩ 19,950                                            perfect
# 7060   ₩ 19,950                                     I hate bugs...
# 7061   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7062   ₩ 19,950  This is an all around great game . Fun to play...
# 7063   ₩ 19,950  Really fun. I hate the lag but that's just my ...
#
#       review_score language
# 0             True  english
# 1             True  english
# 2            False  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7059          True  english
# 7060          True  english
# 7061          True  english
# 7062          True  english
# 7063          True  english
#
# [7064 rows x 9 columns]

# %%
Example1=Example1.drop(['app_id', ], axis=1) # app_id 삭제
Example1 = Example1[Example1['language'] == 'english'] # english 
Example1 = Example1.reset_index(drop=True) # 재정렬
Example1
# Out:
#                 game_name                                        game_genres  \
# 0     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 1     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 2     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 3     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 4     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# ...                   ...                                                ...
# 7059             Grounded                                  Action, Adventure
# 7060             Grounded                                  Action, Adventure
# 7061             Grounded                                  Action, Adventure
# 7062             Grounded                                  Action, Adventure
# 7063             Grounded                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 1     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 2     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 3     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# 4     https://shared.akamai.steamstatic.com/store_it...      21 Dec, 2017
# ...                                                 ...               ...
# 7059  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7060  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7061  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7062  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
# 7063  https://shared.akamai.steamstatic.com/store_it...      27 Sep, 2022
#
#      game_price                                        review_text  \
# 0      가격 정보 없음  the game is generally good, it is even interes...
# 1      가격 정보 없음  I liked it better when it wasnt a free game, b...
# 2      가격 정보 없음                         Cancer bad disgusting game
# 3      가격 정보 없음  Dag komandolarina karsi oynanmadigi surece zevkli
# 4      가격 정보 없음  The game is good overall fun to play but Full ...
# ...         ...                                                ...
# 7059   ₩ 19,950                                            perfect
# 7060   ₩ 19,950                                     I hate bugs...
# 7061   ₩ 19,950  Good game, super fun to play with the homies! ...
# 7062   ₩ 19,950  This is an all around great game . Fun to play...
# 7063   ₩ 19,950  Really fun. I hate the lag but that's just my ...
#
#       review_score language
# 0             True  english
# 1             True  english
# 2            False  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7059          True  english
# 7060          True  english
# 7061          True  english
# 7062          True  english
# 7063          True  english
#
# [7064 rows x 8 columns]

# %%
# Example1 전처리
Example1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7064 entries, 0 to 7063
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_name          7064 non-null   object
#  1   game_genres        7064 non-null   object
#  2   game_image         7064 non-null   object
#  3   game_release_date  7064 non-null   object
#  4   game_price         7064 non-null   object
#  5   review_text        7001 non-null   object
#  6   review_score       7064 non-null   bool
#  7   language           7064 non-null   object
# dtypes: bool(1), object(7)
# memory usage: 393.3+ KB

# %%
Example1['game_name'].isnull()
Example1['game_name'].value_counts() # 개수확인  총합 .sum()
Example1['game_name'].isnull() # null 확인 총합 .sum()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7059    False
# 7060    False
# 7061    False
# 7062    False
# 7063    False
# Name: game_name, Length: 7064, dtype: bool

# %%
Example1['game_genres'].value_counts().sum()
Example1['game_genres'].isnull().sum()
# Out:
# 0

# %%
Example1['game_image'].value_counts().sum()
Example1['game_image'].isnull().sum()
# Out:
# 0

# %%
Example1['language'].value_counts().sum()
Example1['language'].isnull().sum()
# Out:
# 0

# %%
Example1['game_release_date'].value_counts().sum()
Example1['game_release_date'].isnull().sum()
Example1['game_release_date'].value_counts()


# 이탈리아어 월 이름을 영어로 변환하는 사전
month_map = {
    'gen.': 'Jan',
    'feb.': 'Feb',
    'mar.': 'Mar',
    'apr.': 'Apr',
    'mag.': 'May',
    'giu.': 'Jun',
    'lug.': 'Jul',
    'ago.': 'Aug',
    'set.': 'Sep',
    'ott.': 'Oct',
    'nov.': 'Nov',
    'dic.': 'Dec'
}

# 날짜 변환 함수 정의
def parse_date(date_str):
    # 이탈리아어 월 이름을 영어로 변환
    for italian_month, english_month in month_map.items():
        if italian_month in date_str:
            date_str = date_str.replace(italian_month, english_month)

    # 여러 가지 날짜 형식 처리
    try:
        # 'Sep 19, 2024' 형식
        return pd.to_datetime(date_str, format='%b %d, %Y')
    except ValueError:
        pass
    try:
        # '19 Sep, 2024' 형식
        return pd.to_datetime(date_str, format='%d %b, %Y')
    except ValueError:
        pass
    try:
        # '9/set./2024' 형식 (이탈리아어 월 변환 후 처리)
        return pd.to_datetime(date_str, format='%d/%b/%Y')
    except ValueError:
        pass
    
    return pd.NaT  # 변환 실패 시 NaT 반환

# 데이터프레임의 날짜 열 변환
Example1['game_release_date'] = Example1['game_release_date'].apply(parse_date)
Example1['game_release_date'].isnull().sum()
Example1['game_release_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7064 entries, 0 to 7063
# Series name: game_release_date
# Non-Null Count  Dtype
# --------------  -----
# 7064 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 55.3 KB

# %%
Example1['review_score']
Example1['review_score'].isnull().sum()
Example1['review_score'].value_counts()
Example1['review_score'].value_counts().sum()
# Out:
# 7064

# %%
Example1['review_text'].value_counts().sum()
Example1['review_text'].value_counts()
Example1['review_text'].isnull().sum()
Example1['review_text'].isnull()
Example1 = Example1.dropna(subset=['review_text'], axis=0)

# %%
# game_price
Example1['game_price'].value_counts().sum()
# Out:
# 7001

# %%
Example1['game_price'].isnull().sum()
# Out:
# 0

# %%
Example1['game_price'].value_counts()
# Out:
# game_price
# 가격 정보 없음      954
# ₩ 21,500      393
# CDN$ 39.99    350
# CDN$ 79.99    300
# ¥ 208.60      294
# $59.99        290
# CDN$ 31.99    250
# CDN$ 66.99    245
# ₩ 12,950      200
# $12.74        200
# ₩ 69,800      192
# 44.99€        150
# ₩ 38,880      150
# $19.99        150
# ₩ 27,920      150
# ₩ 34,900      149
# ₩ 45,360      147
# ₩ 47,880      100
# ₩ 33,000      100
# ₩ 16,500      100
# CDN$ 7.99     100
# ₩ 6,150       100
# CDN$ 20.09    100
# ₩ 19,950      100
# ¥ 223.00      100
# ₩ 79,800      100
# ₩ 24,800      100
# ₩ 37,800      100
# ₩ 62,400       98
# ₩ 64,800       96
# CDN$ 16.99     50
# $49.99 USD     50
# ₩ 49,800       50
# ₩ 10,250       50
# ₩ 39,900       50
# ₩ 10,850       50
# ₩ 58,800       50
# ₩ 15,500       50
# ₩ 44,800       50
# ₩ 14,020       50
# CDN$ 56.99     50
# ₩ 47,000       50
# CDN$ 46.74     50
# ₩ 62,800       50
# ₩ 9,900        50
# ₩ 24,000       50
# ₩ 32,000       50
# CDN$ 12.24     50
# ₩ 45,490       50
# ₩ 16,000       49
# ¥ 268.00       48
# R$ 199.90      48
# CDN$ 14.81     48
# Name: count, dtype: int64

# %%
# 특정 값 변경
Example1['game_price'] = Example1['game_price'].replace('44,99€', '44.99€') # 

Example1['game_price'] = Example1['game_price'].replace('R$ 199,90', 'R$ 199.90')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\107871597.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].replace('44,99€', '44.99€') #
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\107871597.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].replace('R$ 199,90', 'R$ 199.90')

# %%
# 특정 값 변경
Example1['game_price'] = Example1['game_price'].replace('44,99€', '44.99€') 

Example1['game_price'] = Example1['game_price'].replace('R$ 199,90', 'R$ 199.90')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\4294488823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].replace('44,99€', '44.99€')
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\4294488823.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].replace('R$ 199,90', 'R$ 199.90')

# %%
import re

# 통화 기호에 따라 숫자를 변환하는 함수
def extract_numbers(price_str):
    if isinstance(price_str, str):  # price_str이 문자열인지 확인
        # 통화 기호에 따라 환율을 설정
        if '₩' in price_str:
            multiplier = 1  # 원화: 그대로 사용
        elif 'CDN$' in price_str:
            multiplier = 950  # 캐나다 달러 기준, 예: 1 CAD = 950 KRW
        elif '$' in price_str:
            multiplier = 1300  # 미국 달러 기준, 예: 1 USD = 1300 KRW
        elif '€' in price_str:
            multiplier = 1400  # 유로 기준, 예: 1 EUR = 1400 KRW
        elif '¥' in price_str:
            multiplier = 10  # 엔화 기준, 예: 1 JPY = 10 KRW
        elif 'R$' in price_str:
            multiplier = 300  # 브라질 헤알 기준, 예: 1 BRL = 300 KRW
        else:
            multiplier = 1  # 통화 기호가 없는 경우 그대로 사용

        # 소수점이 포함된 숫자만 추출 (쉼표와 공백 제거)
        numbers = re.sub(r'[^\d.]', '', price_str)
        
        # 추출한 숫자 문자열을 소수로 변환한 후 환율 적용
        return float(numbers) * multiplier if numbers else 0  # 숫자에 통화 단위 곱하기
    return 0  # 문자열이 아닐 경우 0 반환

# 'game_price' 열 변환
Example1['game_price'] = Example1['game_price'].replace('가격 정보 없음', '0')  # 가격 정보가 없는 경우 0으로 대체
Example1['game_price'] = Example1['game_price'].apply(extract_numbers)  # 각 가격 문자열에 대해 함수 적용
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\1318368436.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].replace('가격 정보 없음', '0')  # 가격 정보가 없는 경우 0으로 대체
# C:\Users\user\AppData\Local\Temp\ipykernel_17308\1318368436.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Example1['game_price'] = Example1['game_price'].apply(extract_numbers)  # 각 가격 문자열에 대해 함수 적용

# %%
Example1['game_price'].value_counts()
# Out:
# game_price
# 0.0         954
# 21500.0     393
# 37990.5     350
# 75990.5     300
# 2086.0      294
# 77987.0     290
# 30390.5     250
# 63640.5     245
# 12950.0     200
# 16562.0     200
# 69800.0     192
# 62986.0     150
# 38880.0     150
# 25987.0     150
# 27920.0     150
# 34900.0     149
# 45360.0     147
# 47880.0     100
# 33000.0     100
# 16500.0     100
# 7590.5      100
# 6150.0      100
# 19085.5     100
# 19950.0     100
# 2230.0      100
# 79800.0     100
# 24800.0     100
# 37800.0     100
# 62400.0      98
# 64800.0      96
# 16140.5      50
# 64987.0      50
# 49800.0      50
# 10250.0      50
# 39900.0      50
# 10850.0      50
# 58800.0      50
# 15500.0      50
# 44800.0      50
# 14020.0      50
# 54140.5      50
# 47000.0      50
# 44403.0      50
# 62800.0      50
# 9900.0       50
# 24000.0      50
# 32000.0      50
# 11628.0      50
# 45490.0      50
# 16000.0      49
# 2680.0       48
# 259870.0     48
# 14069.5      48
# Name: count, dtype: int64

# %%
Example1['game_price'].isnull().sum()
# Out:
# 0

# %%
Example1['game_price'].astype(int)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#         ...
# 7059    19950
# 7060    19950
# 7061    19950
# 7062    19950
# 7063    19950
# Name: game_price, Length: 7001, dtype: int32

# %%
Example1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7001 entries, 0 to 7063
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_name          7001 non-null   object
#  1   game_genres        7001 non-null   object
#  2   game_image         7001 non-null   object
#  3   game_release_date  7001 non-null   datetime64[ns]
#  4   game_price         7001 non-null   float64
#  5   review_text        7001 non-null   object
#  6   review_score       7001 non-null   bool
#  7   language           7001 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(1), object(5)
# memory usage: 444.4+ KB

# %%
Example1
# Out:
#                 game_name                                        game_genres  \
# 0     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 1     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 2     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 3     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# 4     PUBG: BATTLEGROUNDS  Action, Adventure, Massively Multiplayer, Free...
# ...                   ...                                                ...
# 7059             Grounded                                  Action, Adventure
# 7060             Grounded                                  Action, Adventure
# 7061             Grounded                                  Action, Adventure
# 7062             Grounded                                  Action, Adventure
# 7063             Grounded                                  Action, Adventure
#
#                                              game_image game_release_date  \
# 0     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 1     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 2     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 3     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# 4     https://shared.akamai.steamstatic.com/store_it...        2017-12-21
# ...                                                 ...               ...
# 7059  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7060  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7061  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7062  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
# 7063  https://shared.akamai.steamstatic.com/store_it...        2022-09-27
#
#       game_price                                        review_text  \
# 0            0.0  the game is generally good, it is even interes...
# 1            0.0  I liked it better when it wasnt a free game, b...
# 2            0.0                         Cancer bad disgusting game
# 3            0.0  Dag komandolarina karsi oynanmadigi surece zevkli
# 4            0.0  The game is good overall fun to play but Full ...
# ...          ...                                                ...
# 7059     19950.0                                            perfect
# 7060     19950.0                                     I hate bugs...
# 7061     19950.0  Good game, super fun to play with the homies! ...
# 7062     19950.0  This is an all around great game . Fun to play...
# 7063     19950.0  Really fun. I hate the lag but that's just my ...
#
#       review_score language
# 0             True  english
# 1             True  english
# 2            False  english
# 3             True  english
# 4             True  english
# ...            ...      ...
# 7059          True  english
# 7060          True  english
# 7061          True  english
# 7062          True  english
# 7063          True  english
#
# [7001 rows x 8 columns]

# %%
Example1.to_csv('finally.csv')

# %%
ex=pd.read_csv('finally.csv')
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         7001 non-null   int64
#  1   game_name          7001 non-null   object
#  2   game_genres        7001 non-null   object
#  3   game_image         7001 non-null   object
#  4   game_release_date  7001 non-null   object
#  5   game_price         7001 non-null   float64
#  6   review_text        7001 non-null   object
#  7   review_score       7001 non-null   bool
#  8   language           7001 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 444.5+ KB
